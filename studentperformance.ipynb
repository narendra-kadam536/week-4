# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

try:
    # Load dataset
    df = pd.read_csv("C:\\Users\\Dell\\Downloads\\student_scores.csv")

    # Validate data
    subjects = ["math", "science", "english", "computer"]
    df[subjects] = df[subjects].apply(pd.to_numeric, errors="coerce")
    df.dropna(inplace=True)

    # Calculate averages
    df["average_score"] = df[subjects].mean(axis=1)
    subject_average = df[subjects].mean()

    print("Subject-wise Average Scores:")
    print(subject_average)

    # Create visualization folder
    os.makedirs("visualizations", exist_ok=True)

    # Chart 1: Subject-wise Average (Bar Chart)
    subject_average.plot(kind="bar", title="Average Marks by Subject")
    plt.xlabel("Subject")
    plt.ylabel("Average Marks")
    plt.tight_layout()
    plt.savefig("visualizations/subject_average_scores.png")
    plt.close()

    # Chart 2: Student-wise Average (Line Chart)
    plt.plot(df["student_id"], df["average_score"], marker="o")
    plt.title("Student Average Performance")
    plt.xlabel("Student ID")
    plt.ylabel("Average Score")
    plt.tight_layout()
    plt.savefig("visualizations/student_average_scores.png")
    plt.close()

except FileNotFoundError:
    print("Dataset file not found. Please check the file path.")
except Exception as e:
    print("An error occurred:", e)
# Out:
# Subject-wise Average Scores:
# math        78.18
# science     76.40
# english     77.18
# computer    79.54
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

def main():
    try:
        # Load dataset
        df = pd.read_csv("C:\\Users\\Dell\\Downloads\\student_scores.csv")
        
        # Subjects list
        subjects = ["math", "science", "english", "computer"]

        # Data cleaning & validation
        df[subjects] = df[subjects].apply(pd.to_numeric, errors="coerce")
        df.dropna(inplace=True)

        # Calculate averages
        df["average_score"] = df[subjects].mean(axis=1)
        subject_avg = df[subjects].mean()

        # Create output folder
        os.makedirs("visualizations", exist_ok=True)

        # -------------------------------
        # Chart 1: Subject-wise Average (Bar Chart)
        # -------------------------------
        subject_avg.plot(kind="bar", title="Average Marks by Subject")
        plt.xlabel("Subjects")
        plt.ylabel("Average Marks")
        plt.tight_layout()
        plt.savefig("visualizations/subject_average_scores.png")
        plt.show()

        # -------------------------------
        # Chart 2: Student-wise Performance (Line Chart)
        # -------------------------------
        plt.plot(df["student_id"], df["average_score"], marker="o")
        plt.title("Student Performance Trend")
        plt.xlabel("Student ID")
        plt.ylabel("Average Score")
        plt.tight_layout()
        plt.savefig("visualizations/student_average_scores.png")
        plt.show()

        # Print insights
        print("\n SUBJECT AVERAGES")
        print(subject_avg)

        print("\n TOP 5 STUDENTS")
        print(df.sort_values(by="average_score", ascending=False).head())

        print("\n LOW PERFORMING STUDENTS (Avg < 70)")
        print(df[df["average_score"] < 70])

    except FileNotFoundError:
        print("CSV file not found. Check the file path.")
    except Exception as e:
        print("Error:", e)

if __name__ == "__main__":
    main()
# Out:
#  SUBJECT AVERAGES
# math        78.18
# science     76.40
# english     77.18
# computer    79.54
# dtype: float64
#
#  TOP 5 STUDENTS
#     student_id  math  science  english  computer  average_score
# 47          48    95       93       94        96          94.50
# 17          18    95       92       94        96          94.25
# 8            9    92       90       91        94          91.75
# 37          38    92       91       90        93          91.50
# 13          14    91       88       90        93          90.50
#
#  LOW PERFORMING STUDENTS (Avg < 70)
#     student_id  math  science  english  computer  average_score
# 2            3    62       58       65        60          61.25
# 4            5    55       60       58        57          57.50
# 7            8    69       65       70        68          68.00
# 10          11    64       62       66        65          64.25
# 14          15    67       69       68        70          68.50
# 18          19    70       68       69        71          69.50
# 19          20    65       64       63        66          64.50
# 22          23    60       59       61        62          60.50
# 26          27    68       67       66        69          67.50
# 30          31    66       65       64        67          65.50
# 34          35    69       68       67        70          68.50
# 39          40    64       63       62        65          63.50
# 44          45    67       66       65        68          66.50
# 48          49    68       67       66        69          67.50
